# %%
#import modules we need to use for this session
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
# PCA module
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn import linear_model
from sklearn import preprocessing
from sklearn.metrics import r2_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Task 1. House price prediction using 311 data
#
# ### Can 311 complaining profile of urban neighborhoods enhance real-estate price prediction?
#
# [Zhu, E., & Sobolevsky, S. (2018). House Price Modeling with Digital Census. arXiv preprint arXiv:1809.03834.]

# %% [markdown]
# Before we tried to use some parameters of the house (size) to predict its price. However notice that location matters as well. Below we upload a sample of more than 14000 individual house sales all around NYC in 2012. Each record together with the parameters of the house also contains important characteristics of the location (zip code) - average income of its residents (accodring to US census), as well as the relative structure of 311 complaints happening in the area.

# %%
REsample=pd.read_csv('https://raw.githubusercontent.com/pratikwatwani/Applied-Data-Science/master/data/NYChome_sales2012.csv',index_col=0)

# %%
len(REsample)
# Out:
# 14611

# %%
REsample.head()
# Out:
#         borough neighborhood  block  ...  year_built  sale_price   sale_date
# 204018        4    LAURELTON  12941  ...        1940           0  2012-01-01
# 217555        2     BATHGATE   3046  ...        1899      345376  2012-04-05
# 217598        2   BAYCHESTER   4707  ...        1950      335700  2012-05-17
# 217599        2   BAYCHESTER   4708  ...        1945      338000  2012-02-03
# 217600        2   BAYCHESTER   4710  ...        1945           0  2012-12-20
#
# [5 rows x 14 columns]

# %%
REsample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14611 entries, 204018 to 301573
# Data columns (total 14 columns):
# borough                   14611 non-null int64
# neighborhood              14611 non-null object
# block                     14611 non-null int64
# lot                       14611 non-null int64
# easement                  0 non-null float64
# building_class_present    14611 non-null object
# address                   14611 non-null object
# zip_code                  14611 non-null int64
# commmercial_units         14611 non-null int64
# land_sq_feet              14611 non-null int64
# gross_sq_feet             14611 non-null int64
# year_built                14611 non-null int64
# sale_price                14611 non-null int64
# sale_date                 14611 non-null object
# dtypes: float64(1), int64(9), object(4)
# memory usage: 1.7+ MB

# %%
main_columns = list(REsample)
main_columns.insert(0, main_columns.pop(main_columns.index('sale_price')))
REsample = REsample.ix[:, main_columns]
REsample.head()
# Out:
#         sale_price  borough neighborhood  ...  gross_sq_feet  year_built   sale_date
# 204018           0        4    LAURELTON  ...           1473        1940  2012-01-01
# 217555      345376        2     BATHGATE  ...           1424        1899  2012-04-05
# 217598      335700        2   BAYCHESTER  ...           1813        1950  2012-05-17
# 217599      338000        2   BAYCHESTER  ...           1813        1945  2012-02-03
# 217600           0        2   BAYCHESTER  ...           1998        1945  2012-12-20
#
# [5 rows x 14 columns]

# %%
#Remove all string columns

string_cols = (REsample.dtypes[REsample.dtypes == "object"].index).to_list()

REsample.drop(labels = string_cols, axis = 1, inplace = True)

# %%
REsample.drop(columns='easement', inplace = True)

# %%
REsample.columns
# Out:
# Index([u'sale_price', u'borough', u'block', u'lot', u'zip_code',
#        u'commmercial_units', u'land_sq_feet', u'gross_sq_feet', u'year_built'],
#       dtype='object')

# %%
#how many houses do we have per each borough?
np.bincount(REsample.borough)
# Out:
# array([   0,  216,  894, 2769, 7288, 3444])

# %%
#split into training (1), validation (2) and test (3) samples
np.random.seed(2018)
splitind=np.random.uniform(size=len(REsample)) #draw samples within low and high limit, each sample is likely to be drawn 
splitind
# Out:
# array([0.88234931, 0.10432774, 0.90700933, ..., 0.86845249, 0.57514979,
#        0.79229244])

# %%
REsample1=REsample.loc[splitind<=0.4] #training
REsample2=REsample.loc[(splitind>0.4)&(splitind<0.7)] #validation
REsample3=REsample.loc[(splitind>=0.7)] #test

# %%
len(REsample1) #loosing around 50 records within sparse zip codes
# Out:
# 5832

# %%
len(REsample2)
# Out:
# 4394

# %%
len(REsample3)
# Out:
# 4385

# %%
# now load and curate 311 data which we're going to use in order to characterize the location

# %%
data311 = pd.read_csv('https://raw.githubusercontent.com/pratikwatwani/Applied-Data-Science/master/data/aggr311.csv' , index_col=0 )
data311.head()
# Out:
#      Zip        Complain  Count
# 1    NaN  Adopt-A-Basket      5
# 2  10001  Adopt-A-Basket      1
# 3  10003  Adopt-A-Basket      1
# 4  10009  Adopt-A-Basket      1
# 5  10010  Adopt-A-Basket      1

# %%
data311.Zip=pd.to_numeric(data311.Zip,errors='coerce') #Take separate series and convert to numeric, coercing when told to, errors = 'coerce' means then invalid parsing will be set as NaN
data311.head()
# Out:
#        Zip        Complain  Count
# 1      NaN  Adopt-A-Basket      5
# 2  10001.0  Adopt-A-Basket      1
# 3  10003.0  Adopt-A-Basket      1
# 4  10009.0  Adopt-A-Basket      1
# 5  10010.0  Adopt-A-Basket      1

# %%
data311=data311.loc[(data311.Zip>=10000)&(data311.Zip<11500)] #take only NYC zip codes

# %%
data311=pd.pivot_table(data311,index='Zip',columns='Complain',values='Count',fill_value=0)

# %%
data311.head()
# Out:
# Complain  APPLIANCE  Adopt-A-Basket  ...  Window Guard  X-Ray Machine/Equipment
# Zip                                  ...
# 10000.0           0               0  ...             0                        0
# 10001.0           0               1  ...             0                        0
# 10002.0          15               0  ...             0                        0
# 10003.0          15               1  ...             0                        0
# 10004.0           0               0  ...             0                        0
#
# [5 rows x 162 columns]

# %%
data311.shape
# Out:
# (264, 162)

# %%
list_311=list(data311.columns)
list_311[:10]
# Out:
# ['APPLIANCE',
#  'Adopt-A-Basket',
#  'Air Quality',
#  'Animal Abuse',
#  'Animal Facility - No Permit',
#  'Animal in a Park',
#  'Asbestos',
#  'BEST/Site Safety',
#  'Beach/Pool/Sauna Complaint',
#  'Bike Rack Condition']

# %%
Total311=data311.sum(axis=1) #total 311 activity per zip code
Total311.head()
# Out:
# Zip
# 10000.0      114
# 10001.0     6829
# 10002.0    11276
# 10003.0    11269
# 10004.0     1540
# dtype: int64

# %%
data311.head()
# Out:
# Complain  APPLIANCE  Adopt-A-Basket  ...  Window Guard  X-Ray Machine/Equipment
# Zip                                  ...
# 10000.0           0               0  ...             0                        0
# 10001.0           0               1  ...             0                        0
# 10002.0          15               0  ...             0                        0
# 10003.0          15               1  ...             0                        0
# 10004.0           0               0  ...             0                        0
#
# [5 rows x 162 columns]

# %%
data311=data311.div(data311.sum(axis=1), axis=0) #normalize activity of various categories within zip code by total
data311=data311.loc[Total311>100] #keep only those zip codes having sufficient activity
data311.head()
# Out:
# Complain  APPLIANCE  Adopt-A-Basket  ...  Window Guard  X-Ray Machine/Equipment
# Zip                                  ...
# 10000.0    0.000000        0.000000  ...           0.0                      0.0
# 10001.0    0.000000        0.000146  ...           0.0                      0.0
# 10002.0    0.001330        0.000000  ...           0.0                      0.0
# 10003.0    0.001331        0.000089  ...           0.0                      0.0
# 10004.0    0.000000        0.000000  ...           0.0                      0.0
#
# [5 rows x 162 columns]

# %%
len(data311) #only 179 zip codes with reliable data left
# Out:
# 179

# %%
#data311.columns  = data311.columns.str.lower()
#data311.columns  =data311.columns.str.split(' ').str.get(0)

# %%
#data311.columns  =data311.columns.str.split('-').str.get(0)
#data311.columns  =data311.columns.str.split('/').str.get(0)

# %%
data311.index.rename('zip_code', inplace = True)

# %% [markdown]
# #### Q1. Run linear regression 'sale_price ~ gross_sq_feet+land_sq_feet+year_built' over the training data

# %% [markdown]
# ## REsample1 is the training data

# %%
REsample1.head()
# Out:
#         sale_price  borough  block  ...  land_sq_feet  gross_sq_feet  year_built
# 217555      345376        2   3046  ...          1964           1424        1899
# 217599      338000        2   4708  ...          1710           1813        1945
# 217605      250000        2   4715  ...          2514           1690        1950
# 217609      249600        2   4724  ...          2283           1588        1910
# 217610      313000        2   4725  ...          1710           1690        1945
#
# [5 rows x 9 columns]

# %%
REsample1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5832 entries, 217555 to 301570
# Data columns (total 9 columns):
# sale_price           5832 non-null int64
# borough              5832 non-null int64
# block                5832 non-null int64
# lot                  5832 non-null int64
# zip_code             5832 non-null int64
# commmercial_units    5832 non-null int64
# land_sq_feet         5832 non-null int64
# gross_sq_feet        5832 non-null int64
# year_built           5832 non-null int64
# dtypes: int64(9)
# memory usage: 455.6 KB

# %%
lm  = smf.ols(formula = 'sale_price ~ gross_sq_feet+land_sq_feet+year_built', data = REsample1).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             sale_price   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     342.8
# Date:                Wed, 20 Nov 2019   Prob (F-statistic):          5.23e-205
# Time:                        17:09:51   Log-Likelihood:                -88308.
# No. Observations:                5832   AIC:                         1.766e+05
# Df Residuals:                    5828   BIC:                         1.767e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      7.637e+06   8.92e+05      8.561      0.000    5.89e+06    9.39e+06
# gross_sq_feet   429.2542     13.783     31.144      0.000     402.235     456.273
# land_sq_feet    -33.5074      4.199     -7.979      0.000     -41.740     -25.275
# year_built    -4081.0137    460.200     -8.868      0.000   -4983.177   -3178.851
# ==============================================================================
# Omnibus:                    10546.282   Durbin-Watson:                   1.538
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17222068.188
# Skew:                          13.092   Prob(JB):                         0.00
# Kurtosis:                     267.928   Cond. No.                     3.90e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.9e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print('The R2 Score over Training Data is: {}'.format(r2_score(REsample1.sale_price, lm.predict())))
# Out:
# The R2 Score over Training Data is: 0.149987575604

# %% [markdown]
# #### Q2. Add 311 data corresponding to the zip code of the house location to REsample1,2,3
# in order to characterize the house's neighborhood by merging the dataframes REsample1,2,3 with data311 by zip code. Name merged dataframes REsample1_311, REsample2_311, REsample3_311
# rename 311 columns to F1,F2,... for easier formulae engineering
# but keep the original names as a dictionary {'F1':'APPLIANCE', ...}

# %%
data311.columns = ['F%d'%p for p in range(0,len(data311.columns))]

# %%
REsample1_311 = REsample1.merge(data311, on = 'zip_code')
REsample2_311 = REsample2.merge(data311, on = 'zip_code')
REsample3_311 = REsample3.merge(data311, on = 'zip_code')

# %% [markdown]
# #### Q3. Run the linear model with 311
# We need to add 311 features in addition to the gross_sq_feet,land_sq_feet,year_built used before. So regression will include both - house characteristics as well as 311 features of the location
# Train the model over the training sample REsample1_311 and test over the test sample REsample3_311,
# report training and test R2

# %%
REsample1_311.head()
# Out:
#    sale_price  borough  block  lot  ...      F158      F159      F160  F161
# 0      345376        2   3046   42  ...  0.000268  0.028311  0.000000   0.0
# 1      168324        2   2790   53  ...  0.000268  0.028311  0.000000   0.0
# 2      250000        2   2791   36  ...  0.000268  0.028311  0.000000   0.0
# 3      211000        2   2802   33  ...  0.000268  0.028311  0.000000   0.0
# 4      338000        2   4708   48  ...  0.000708  0.046250  0.000101   0.0
#
# [5 rows x 171 columns]

# %%
'sale_price ~ gross_sq_feet+land_sq_feet+year_built'+'+'+'+'.join(REsample1_311.columns[(len(REsample1_311.columns)-len(data311.columns)):])
# Out:
# 'sale_price ~ gross_sq_feet+land_sq_feet+year_...'

# %%
#resample1311preds = [[] for i in range(REsample1_311.shape[0])]
#formula = 'sale_price ~ gross_sq_feet+land_sq_feet+year_built'+'+'+'+'.join(REsample1_311.columns[14:])

lms  = smf.ols(formula = 'sale_price ~ gross_sq_feet+land_sq_feet+year_built'+'+'+'+'.join(REsample1_311.columns[(len(REsample1_311.columns)-len(data311.columns)):]), data = REsample1_311).fit()
print(lms.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             sale_price   R-squared:                       0.448
# Model:                            OLS   Adj. R-squared:                  0.433
# Method:                 Least Squares   F-statistic:                     30.23
# Date:                Wed, 20 Nov 2019   Prob (F-statistic):               0.00
# Time:                        17:09:52   Log-Likelihood:                -85271.
# No. Observations:                5710   AIC:                         1.708e+05
# Df Residuals:                    5560   BIC:                         1.718e+05
# Df Model:                         149
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.873e+08    6.1e+07     -3.071      0.002   -3.07e+08   -6.77e+07
# gross_sq_feet   160.0441     14.642     10.931      0.000     131.340     188.748
# land_sq_feet      7.1463      4.080      1.751      0.080      -0.853      15.145
# year_built      -48.2619    538.026     -0.090      0.929   -1103.003    1006.480
# F0             1.711e+08   1.74e+08      0.982      0.326   -1.71e+08    5.13e+08
# F1            -4.882e+09   1.92e+09     -2.545      0.011   -8.64e+09   -1.12e+09
# F2             2.114e+08   1.27e+08      1.666      0.096   -3.74e+07     4.6e+08
# F3             5.596e+08   2.19e+08      2.556      0.011     1.3e+08    9.89e+08
# F4             -6.37e+07    1.3e+09     -0.049      0.961   -2.61e+09    2.48e+09
# F5            -1.763e+08   1.18e+08     -1.489      0.137   -4.08e+08    5.58e+07
# F6             3.628e+07   3.25e+08      0.112      0.911   -6.01e+08    6.73e+08
# F7            -3.062e+08   4.36e+08     -0.703      0.482   -1.16e+09    5.48e+08
# F153          -1.228e+09   8.19e+08     -1.500      0.134   -2.83e+09    3.77e+08
# F154           2.671e+08   1.02e+08      2.617      0.009     6.7e+07    4.67e+08
# F155           4.085e+08   1.41e+08      2.887      0.004    1.31e+08    6.86e+08
# F156           2.609e+08   1.96e+08      1.332      0.183   -1.23e+08    6.45e+08
# F157            3.09e+08   9.36e+07      3.302      0.001    1.26e+08    4.93e+08
# F158           1.348e+09   3.11e+08      4.327      0.000    7.37e+08    1.96e+09
# F159           1.819e+08   6.37e+07      2.854      0.004    5.69e+07    3.07e+08
# F160           3.744e+09   1.55e+09      2.412      0.016       7e+08    6.79e+09
# F161           5.046e+08   1.33e+09      0.380      0.704    -2.1e+09    3.11e+09
# ==============================================================================
# Omnibus:                     8298.035   Durbin-Watson:                   2.391
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12324629.949
# Skew:                           8.102   Prob(JB):                         0.00
# Kurtosis:                     230.024   Cond. No.                     1.18e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.1e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
#R2 over training
print("R2_Score for Training Data: {}".format(r2_score(REsample1_311.sale_price, lms.predict(REsample1_311))))
# Out:
# R2_Score for Training Data: 0.447555858667

# %%
#R2 over testing
print("R2_Score for Test Data: {}".format(r2_score(REsample3_311.sale_price, lms.predict(REsample3_311))))
# Out:
# R2_Score for Test Data: 0.278805746926

# %%
print("R2 over Testing is {}".format(1-(((REsample3_311.sale_price-lms.predict(REsample3_311))**2).sum()/((REsample3_311.sale_price-REsample3_311.sale_price.mean())**2).sum())))
# Out:
# R2 over Testing is 0.278805746926

# %% [markdown]
# #### Q4. Apply regularization
# Train Ridge and Lasso over REsample1_311 with an arbitrary default parameter $\alpha=1$.
# Then evaluate their out-of-sample performance over REsample3_311
# Make sure to scale the features in all three samples first, learning the scaler over the training sample

# %%
#Learning metrics from training set
mu=REsample1_311.iloc[:,1:].mean()
sigma=REsample1_311.iloc[:,1:].std()


REsample1_311.iloc[:,1:]=(REsample1_311.iloc[:,1:]-mu)/sigma
REsample2_311.iloc[:,1:]=(REsample2_311.iloc[:,1:]-mu)/sigma
REsample3_311.iloc[:,1:]=(REsample3_311.iloc[:,1:]-mu)/sigma

# %%
al = REsample1_311.iloc[:,1:].copy()
ab = REsample3_311.iloc[:,1:].copy()
ag = REsample2_311.iloc[:,1:].copy()


al.fillna(inplace = True, value = 0)
ab.fillna(inplace = True, value = 0)
ag.fillna(inplace = True, value = 0)

# %%
REsample1_311.head()
# Out:
#    sale_price   borough     block  ...      F159      F160      F161
# 0      345376 -2.111829 -0.893403  ... -0.937235 -0.278540 -0.208687
# 1      168324 -2.111829 -0.965613  ... -0.937235 -0.278540 -0.208687
# 2      250000 -2.111829 -0.965331  ... -0.937235 -0.278540 -0.208687
# 3      211000 -2.111829 -0.962229  ... -0.937235 -0.278540 -0.208687
# 4      338000 -2.111829 -0.424600  ... -0.155079  1.146794 -0.208687
#
# [5 rows x 171 columns]

# %%
Ridge=linear_model.Ridge(fit_intercept=True, alpha=1)
Ridge.fit(al,REsample1_311['sale_price'])

print("The R2 for Ridge Training is: {}".format(r2_score(REsample1_311['sale_price'],Ridge.predict(al))))
print("The R2 for Ridge Testing is: {}".format(r2_score(REsample3_311['sale_price'],Ridge.predict(ab))))
# Out:
# The R2 for Ridge Training is: 0.448843712587
# The R2 for Ridge Testing is: 0.280432404213

# %% [markdown]
# # Perform Lasso

# %%
Lasso=linear_model.Lasso(fit_intercept=True, alpha=1)
Lasso.fit(al,REsample1_311['sale_price'])

print("The R2 for Lasso Training is: {0}".format(r2_score(REsample1_311['sale_price'],Lasso.predict(al))))
print("The R2 for Lasso Testing is: {0}".format(r2_score(REsample3_311['sale_price'],Lasso.predict(ab))))
# Out:
# The R2 for Lasso Training is: 0.448655805942
# The R2 for Lasso Testing is: 0.275912134494

# %% [markdown]
# #### Q5. Perform parameter selection for Lasso and Ridge over validation sample
# try exponential range -exp(10)...exp(20) with 100 values in it
#
# Visualize the validation R2 vs alpha
#
# For the optimal alpha evaluate performance of the models over the test set

# %%
def Regularization_fit_alpha(model,X_train,y_train,X_valid,y_valid,alphas,Graph=False, logl=False):

    R_2_OS=[] 
    if model==1:
        RM = lambda a: linear_model.Ridge(fit_intercept=True, alpha=a)
        model_label='Ridge'
    else:
        RM = lambda a: linear_model.Lasso(fit_intercept=True, alpha=a)
        model_label='Lasso'
    
    best_R2 = -1
    best_alpha = alphas[0]
    best_coefs = []
    
    for a in alphas: 
        lm = RM(a) 
        lm.fit(X_train,y_train)  
        y_predict=lm.predict(X_valid) 
        R_2_OS_=r2_score(y_valid,y_predict)
        R_2_OS.append(R_2_OS_)
        if R_2_OS_ > best_R2: 
            best_R2 = R_2_OS_
            best_alpha = a
            best_coefs = lm.coef_
    
    if Graph==True: 
        plt.figure(figsize = (15,10))
        plt.title('OS-R-squared for different Alpha')
        if logl: 
            plt.xlabel('ln(Alpha)')
            l=np.log(alphas)
            bl=np.log(best_alpha)
        else:
            plt.xlabel('Alpha')
            l=alphas
            bl=best_alpha
        plt.ylim((-0.1,1))
        plt.plot(l,R_2_OS,'b',label=model_label)
        plt.legend(loc='upper right')
        plt.ylabel('R-squared')
        plt.axvline(bl,color='r',linestyle='--')

        plt.show()
    
    return [best_alpha,best_R2,best_coefs]

# %%
alphas = np.exp(np.linspace(-10.0,20.0,100)) 
for x in range(1,3):
  if x ==1:
    [alpha_optimalR, best_R2R, best_coefsR]=Regularization_fit_alpha(x,al,REsample1_311['sale_price'],ag,REsample2_311['sale_price'],alphas,Graph=True,logl=True)
    print('Optimal alpha for Ridge={0}, best OS R_2={1}'.format(alpha_optimalR,best_R2R))
  else:
    [alpha_optimalL, best_R2L, best_coefsL]=Regularization_fit_alpha(x,al,REsample1_311['sale_price'],ag,REsample2_311['sale_price'],alphas,Graph=True,logl=True)
    print('Optimal alpha for Lasso={0}, best OS R_2={1}'.format(alpha_optimalL,best_R2L))
# Out:
# Optimal alpha for Ridge=1063.90030765, best OS R_2=0.292467916957
# Optimal alpha for Lasso=12015.3393777, best OS R_2=0.304166985308

# %%
Lasso=linear_model.Lasso(fit_intercept=True, alpha=alpha_optimalL)
Lasso.fit(al,REsample1_311['sale_price'])

print("The R2 for Lasso Training is: {0}".format(r2_score(REsample1_311['sale_price'],Lasso.predict(al))))
print("The R2 for Lasso Testing is: {0}".format(r2_score(REsample3_311['sale_price'],Lasso.predict(ab))))
# Out:
# The R2 for Lasso Training is: 0.39027381781
# The R2 for Lasso Testing is: 0.364407613415

# %%
Ridge=linear_model.Ridge(fit_intercept=True, alpha=alpha_optimalR)
Ridge.fit(al,REsample1_311['sale_price'])

print("The R2 for Ridge Training is: {}".format(r2_score(REsample1_311['sale_price'],Ridge.predict(al))))
print("The R2 for Ridge Testing is: {}".format(r2_score(REsample3_311['sale_price'],Ridge.predict(ab))))
# Out:
# The R2 for Ridge Training is: 0.403637385528
# The R2 for Ridge Testing is: 0.340065280335

# %% [markdown]
# #### Task 2. Model Mean income of the zip code population using 311 profile of the neighborhood

# %%
#load the data
dataIncome=pd.read_csv("https://raw.githubusercontent.com/pratikwatwani/Applied-Data-Science/master/data/MeanZIP.csv",index_col=0)
dataIncome=dataIncome.apply(pd.to_numeric, errors='coerce')
dataIncome=dataIncome.loc[dataIncome.Mean>0]
dataIncome.head()
# Out:
#           Median        Mean    Pop
# Zip
# 1001  56662.5735  66687.7509  16445
# 1002  49853.4177  75062.6343  28069
# 1003  28462.0000  35121.0000   8491
# 1005  75423.0000  82442.0000   4798
# 1007  79076.3540  85801.9750  12962

# %%
dataIncome.isna().values.any()
# Out:
# False

# %%
dataIncome = dataIncome.iloc[:,[1,0,2]]
dataIncome.head()
# Out:
#             Mean      Median    Pop
# Zip
# 1001  66687.7509  56662.5735  16445
# 1002  75062.6343  49853.4177  28069
# 1003  35121.0000  28462.0000   8491
# 1005  82442.0000  75423.0000   4798
# 1007  85801.9750  79076.3540  12962

# %%
dataIncome.index.rename('zip_code', inplace = True)

# %%
#split into training (1), validation (2) and test (3) samples
np.random.seed(2018)
splitind=np.random.uniform(size=len(dataIncome))
dataIncome1=dataIncome.loc[splitind<=0.4]
dataIncome2=dataIncome.loc[(splitind>0.4)&(splitind<0.7)]
dataIncome3=dataIncome.loc[(splitind>=0.7)]

# %%
dataIncome1.isna().values.any()
# Out:
# False

# %%
train = dataIncome1.merge(data311, on = 'zip_code') #Training
validation = dataIncome2.merge(data311, on = 'zip_code') #Validation
test = dataIncome3.merge(data311, on = 'zip_code') #Testing

# %%
train.isna().values.any()
# Out:
# False

# %% [markdown]
# #### Q1. Perform regularied regression of Mean income of the zip code vs its 311 profile
# Train Ridge and Lasso over dataIncome1 with an arbitrary default parameter $\alpha=100$.
# Then evaluate their out-of-sample performance over dataIncome3
# Make sure to scale the features in all three samples first, learning the scaler over the training sample

# %%
train.head()
# Out:
#                  Mean       Median    Pop  ...      F159      F160  F161
# zip_code                                   ...
# 10003     139330.9968   89998.5339  53609  ...  0.028219  0.000000   0.0
# 10005     163762.6601  115133.2855   1517  ...  0.019726  0.000000   0.0
# 10006     156776.0000  111220.0000    972  ...  0.032051  0.000000   0.0
# 10009      78138.2679   56615.2777  56975  ...  0.033420  0.000104   0.0
# 10012     135998.6472   81316.7066  26464  ...  0.029246  0.000000   0.0
#
# [5 rows x 165 columns]

# %%
mu=train.iloc[:,1:].mean()
sigma=train.iloc[:,1:].std()

# %%
sigma[sigma==0.000].index
# Out:
# Index([u'F80', u'F107', u'F114'], dtype='object')

# %%
filter_cols = sigma[sigma==0.000].index

# %%
train.iloc[:,1:]=(train.iloc[:,1:]-mu)/sigma
validation.iloc[:,1:]=(validation.iloc[:,1:]-mu)/sigma
test.iloc[:,1:]=(test.iloc[:,1:]-mu)/sigma

# %% [markdown]
# # Removing features with 0 standard deviation!
# ## F80, F107, F114

# %%
train.drop(labels=filter_cols, axis = 1, inplace = True)
validation.drop(labels=filter_cols, axis = 1, inplace = True)
test.drop(labels=filter_cols, axis = 1, inplace = True)

# %%
train.columns[50:100]
# Out:
# Index([u'F47', u'F48', u'F49', u'F50', u'F51', u'F52', u'F53', u'F54', u'F55',
#        u'F56', u'F57', u'F58', u'F59', u'F60', u'F61', u'F62', u'F63', u'F64',
#        u'F65', u'F66', u'F67', u'F68', u'F69', u'F70', u'F71', u'F72', u'F73',
#        u'F74', u'F75', u'F76', u'F77', u'F78', u'F79', u'F81', u'F82', u'F83',
#        u'F84', u'F85', u'F86', u'F87', u'F88', u'F89', u'F90', u'F91', u'F92',
#        u'F93', u'F94', u'F95', u'F96', u'F97'],
#       dtype='object')

# %%
train.head()
# Out:
#                  Mean    Median       Pop  ...      F159      F160      F161
# zip_code                                   ...
# 10003     139330.9968  0.988798  0.514745  ... -0.567976 -0.409055 -0.227731
# 10005     163762.6601  1.911296 -1.690559  ... -1.008493 -0.409055 -0.227731
# 10006     156776.0000  1.767670 -1.713631  ... -0.369203 -0.409055 -0.227731
# 10009      78138.2679 -0.236436  0.657243  ... -0.298219  1.135794 -0.227731
# 10012     135998.6472  0.670157 -0.634433  ... -0.514690 -0.409055 -0.227731
#
# [5 rows x 162 columns]

# %%
train.notnull().values.all()
# Out:
# True

# %%
len(train.columns)
# Out:
# 162

# %%
Lasso=linear_model.Lasso(fit_intercept=False, alpha=100)

Lasso.fit(train.iloc[:,3:],train['Mean'])

print("The R2 for Lasso Training is: {0}".format(r2_score(train['Mean'],Lasso.predict(train.iloc[:,3:]))))
print("The R2 for Lasso Testing is: {0}".format(r2_score(test['Mean'],Lasso.predict(test.iloc[:,3:]))))
# Out:
# The R2 for Lasso Training is: -2.73022649638
# The R2 for Lasso Testing is: -5.91141369371

# %%
Ridge=linear_model.Ridge(fit_intercept=True, alpha=100)
Ridge.fit(train.iloc[:,3:],train['Mean'])

print("The R2 for Ridge Training is: {0}".format(r2_score(train['Mean'],Ridge.predict(train.iloc[:,3:]))))
print("The R2 for Ridge Testing is: {0}".format(r2_score(test['Mean'],Ridge.predict(test.iloc[:,3:]))))
# Out:
# The R2 for Ridge Training is: 0.946033734613
# The R2 for Ridge Testing is: 0.206429562522

# %% [markdown]
# #### Q2. Perform parameter selection for Lasso and Ridge over validation sample
# try exponential range exp(-10)...exp(20) with 100 values in it
#
# Visualize the validation R2 vs alpha
#
# For the optimal alpha evaluate performance of the models over the test set.
#
# Why do you think performance does not look that good, especially for one of the models?

# %%
train.head(2)
# Out:
#                  Mean    Median       Pop  ...      F159      F160      F161
# zip_code                                   ...
# 10003     139330.9968  0.988798  0.514745  ... -0.567976 -0.409055 -0.227731
# 10005     163762.6601  1.911296 -1.690559  ... -1.008493 -0.409055 -0.227731
#
# [2 rows x 162 columns]

# %%
alphas = np.exp(np.linspace(-10.0,20.0,100)) 
for x in range(1,3):
  if x ==1:
    print('X: {}'.format(x))
    [alpha_optimalR, best_R2R, best_coefsR]=Regularization_fit_alpha(x,train.iloc[:,3:],train['Mean'],validation.iloc[:,3:],validation['Mean'],alphas,Graph=True,logl=True)
    print('Optimal alpha for Ridge={0}, best OS R_2={1}'.format(alpha_optimalR,best_R2R))
  else:
    print('X: {}'.format(x))
    [alpha_optimalL, best_R2L, best_coefsL]=Regularization_fit_alpha(x,train.iloc[:,3:],train['Mean'],validation.iloc[:,3:],validation['Mean'],alphas,Graph=True,logl=True)
    print('Optimal alpha for Lasso={0}, best OS R_2={1}'.format(alpha_optimalL,best_R2L))
# Out:
# X: 1
# Optimal alpha for Ridge=4.53999297625e-05, best OS R_2=0.396850709465
# X: 2
# Optimal alpha for Lasso=2640.66980715, best OS R_2=0.714266345833

# %%
Lasso=linear_model.Lasso(fit_intercept=True, alpha=alpha_optimalL)
Lasso.fit(train.iloc[:,3:],train['Mean'])

print("The R2 for Lasso Training is: {0}".format(r2_score(train['Mean'],Lasso.predict(train.iloc[:,3:]))))
print("The R2 for Lasso Testing is: {0}".format(r2_score(test['Mean'],Lasso.predict(test.iloc[:,3:]))))
# Out:
# The R2 for Lasso Training is: 0.932449577353
# The R2 for Lasso Testing is: -0.831684178259

# %%
Ridge=linear_model.Ridge(fit_intercept=True, alpha=alpha_optimalR)
Ridge.fit(train.iloc[:,3:],train['Mean'])

print("The R2 for Ridge Training is: {0}".format(r2_score(train['Mean'],Ridge.predict(train.iloc[:,3:]))))
print("The R2 for Ridge Testing is: {0}".format(r2_score(test['Mean'],Ridge.predict(test.iloc[:,3:]))))
# Out:
# The R2 for Ridge Training is: 1.0
# The R2 for Ridge Testing is: -0.527969650275

# %% [markdown]
# ## One of the reasons why the performance suffers is because of the requirement to drop certain features, furthermore, the split of the data is not accurate leading in the performance drop in the R2 scores leading on to the negative scale. If we consider the above case using simple linear regression, the results seem out to be positive, unlike in regularization where the scores are negative, which means the regularization is not a very good approach to this problem. Lasso and Ridge both performed very well on the Training sets, but possibly couldn't perform good on Test data, Lasso even worse on the Test Data! Which implies that Lasso overfitted the training data, and hence observes a performance degradation when checking test with R2 results.
